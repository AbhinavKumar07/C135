# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavKumar07/C135/blob/main/C135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-NASA-Exoplanet-Processed-Data
# Out:
# fatal: destination path 'PRO-NASA-Exoplanet-Processed-Data' already exists and is not an empty directory.

# %%
import csv

rows = []

with open("/content/PRO-NASA-Exoplanet-Processed-Data/main.csv" , "r") as f:
  csvreader = csv.reader(f)

  for row in csvreader:
    rows.append(row)

headers = rows[0]
planet_data_rows = rows[1:]

print(headers)
print(planet_data_rows[0])
# Out:
# ['id', 'name', 'light_years_from_earth', 'planet_mass', 'stellar_magnitude', 'discovery_date', 'planet_type', 'planet_radius', 'orbital_radius', 'orbital_period', 'eccentricity', 'solar_system_name', 'planet_discovery_method', 'planet_orbital_inclination', 'planet_density', 'right_ascension', 'declination', 'host_temperature', 'host_mass', 'host_radius']
# ['0', '11 Comae Berenices b', '305', '19.4 Jupiters', '4.74', '2007', 'Gas Giant', '1.08 x Jupiter', '1.29 AU', '326 days', '0.23', '11 Com', 'Radial Velocity', '', '', '12h20m43.03s', '+17d47m34.3s', '4742', '2.7', '19']

# %%
solar_system_planet_count = {}

for planet_data in planet_data_rows:
  if solar_system_planet_count.get(planet_data[11]): #Solar_system name
    solar_system_planet_count[planet_data[11]] += 1
  else:
    solar_system_planet_count[planet_data[11]] = 1
print(solar_system_planet_count)
# Out:
# {'11 Com': 1, '11 UMi': 1, '14 And': 1, '14 Her': 1, '16 Cyg B': 1, '18 Del': 1, '1RXS J160929.1-210524': 1, '24 Boo': 1, '24 Sex': 2, '2MASS J01033563-5515561 A': 1, '2MASS J01225093-2439505': 1, '2MASS J02192210-3925225': 1, '2MASS J04414489+2301513': 1, '2MASS J12073346-3932539': 1, '2MASS J19383260+4603591': 1, '2MASS J21402931+1625183 A': 1, '2MASS J22362452+4751425': 1, '30 Ari B': 1, '4 UMa': 1, '42 Dra': 1, '47 UMa': 3, '51 Eri': 1, '51 Peg': 1, '55 Cnc': 5, '6 Lyn': 1, '61 Vir': 3, '7 CMa': 2, '70 Vir': 1, '75 Cet': 1, '8 UMi': 1, '81 Cet': 1, '91 Aqr': 1, 'AB Pic': 1, 'alf Ari': 1, 'alf Tau': 1, 'AU Mic': 1, 'BD+03 2562': 1, 'BD+14 4559': 1, 'BD+15 2375': 1, 'BD+15 2940': 1, 'BD+20 2457': 2, 'BD+20 274': 1, 'BD+20 594': 1, 'BD+48 738': 1, 'BD+48 740': 1, 'BD+49 828': 1, 'BD-06 1339': 2, 'BD-08 2823': 2, 'BD-10 3166': 1, 'BD-11 4672': 2, 'BD-13 2130': 1, 'BD-17 63': 1, 'bet Cnc': 1, 'bet Pic': 2, 'bet UMi': 1, 'CFBDSIR J145829+101343': 1, 'CHXR 73': 1, 'CI Tau': 1, 'CoRoT-1': 1, 'CoRoT-10': 1, 'CoRoT-11': 1, 'CoRoT-12': 1, 'CoRoT-13': 1, 'CoRoT-14': 1, 'CoRoT-16': 1, 'CoRoT-17': 1, 'CoRoT-18': 1, 'CoRoT-19': 1, 'CoRoT-2': 1, 'CoRoT-20': 2, 'CoRoT-21': 1, 'CoRoT-22': 1, 'CoRoT-23': 1, 'CoRoT-24': 2, 'CoRoT-25': 1, 'CoRoT-26': 1, 'CoRoT-27': 1, 'CoRoT-28': 1, 'CoRoT-29': 1, 'CoRoT-3': 1, 'CoRoT-30': 1, 'CoRoT-31': 1, 'CoRoT-4': 1, 'CoRoT-5': 1, 'CoRoT-6': 1, 'CoRoT-7': 2, 'CoRoT-8': 1, 'CoRoT-9': 1, 'CoRoTID 223977153': 1, 'CT Cha': 1, 'DE CVn': 1, 'DENIS-P J082303.1-491201': 1, 'DH Tau': 1, 'DMPP-1': 4, 'DMPP-2': 1, 'DMPP-3 A': 1, 'DP Leo': 1, 'DS Tuc A': 1, 'EPIC 201238110': 1, 'EPIC 201497682': 1, 'K2-166': 2, 'K2-16': 3, 'K2-50': 2, 'EPIC 201841433': 1, 'K2-168': 2, 'EPIC 206024342': 1, 'EPIC 206032309': 1, 'EPIC 206042996': 1, 'EPIC 206215704': 1, 'EPIC 206317286': 1, 'EPIC 211822797': 1, 'EPIC 211945201': 1, 'EPIC 212297394': 1, 'EPIC 212424622': 1, 'EPIC 212499991': 1, 'EPIC 212587672': 1, 'EPIC 212737443': 2, 'K2-282': 2, 'EPIC 220674823': 2, 'EPIC 246851721': 1, 'EPIC 248847494': 1, 'EPIC 249893012': 3, 'eps CrB': 1, 'eps Eri': 1, 'eps Ind A': 1, 'eps Tau': 1, 'FU Tau': 1, 'G 9-40': 1, 'gam 1 Leo': 1, 'gam Cep': 1, 'gam Lib': 2, 'GJ 1061': 3, 'GJ 1132': 2, 'GJ 1148': 2, 'GJ 1214': 1, 'GJ 1252': 1, 'GJ 1265': 1, 'GJ 143': 2, 'GJ 15 A': 2, 'GJ 160.2': 1, 'GJ 163': 3, 'GJ 179': 1, 'GJ 180': 3, 'GJ 2056': 1, 'GJ 229': 2, 'GJ 27.1': 1, 'GJ 273': 2, 'GJ 3021': 1, 'GJ 3082': 1, 'GJ 3138': 3, 'GJ 317': 2, 'GJ 328': 1, 'GJ 3293': 4, 'GJ 3323': 2, 'GJ 3341': 1, 'GJ 338 B': 1, 'GJ 3470': 1, 'GJ 3512': 1, 'GJ 357': 3, 'GJ 3634': 1, 'GJ 3779': 1, 'GJ 3942': 1, 'GJ 3998': 2, 'GJ 411': 1, 'GJ 422': 1, 'GJ 4276': 1, 'GJ 433': 3, 'GJ 436': 1, 'GJ 480': 1, 'GJ 504': 1, 'GJ 536': 1, 'GJ 581': 3, 'GJ 625': 1, 'GJ 649': 1, 'GJ 667 C': 5, 'GJ 674': 1, 'GJ 676 A': 4, 'GJ 682': 2, 'GJ 685': 1, 'GJ 687': 2, 'GJ 832': 2, 'GJ 849': 1, 'GJ 86': 1, 'GJ 876': 4, 'GJ 887': 2, 'GJ 9066': 2, 'GJ 96': 1, 'GJ 9827': 3, 'Gl 378': 1, 'Gl 49': 1, 'Gl 686': 1, 'GQ Lup': 1, 'GSC 06214-00210': 1, 'GU Psc': 1, 'HAT-P-1': 1, 'HAT-P-11': 2, 'HAT-P-12': 1, 'HAT-P-13': 2, 'HAT-P-14': 1, 'HAT-P-15': 1, 'HAT-P-16': 1, 'HAT-P-17': 2, 'HAT-P-18': 1, 'HAT-P-19': 1, 'HAT-P-2': 1, 'HAT-P-20': 1, 'HAT-P-21': 1, 'HAT-P-22': 1, 'HAT-P-23': 1, 'HAT-P-24': 1, 'HAT-P-25': 1, 'HAT-P-26': 1, 'HAT-P-27': 1, 'HAT-P-28': 1, 'HAT-P-29': 1, 'HAT-P-3': 1, 'HAT-P-30': 1, 'HAT-P-31': 1, 'HAT-P-32': 1, 'HAT-P-33': 1, 'HAT-P-34': 1, 'HAT-P-35': 1, 'HAT-P-36': 1, 'HAT-P-37': 1, 'HAT-P-38': 1, 'HAT-P-39': 1, 'HAT-P-4': 1, 'HAT-P-40': 1, 'HAT-P-41': 1, 'HAT-P-42': 1, 'HAT-P-43': 1, 'HAT-P-44': 2, 'HAT-P-45': 1, 'HAT-P-46': 1, 'HAT-P-49': 1, 'HAT-P-5': 1, 'HAT-P-50': 1, 'HAT-P-51': 1, 'HAT-P-52': 1, 'HAT-P-53': 1, 'HAT-P-54': 1, 'HAT-P-55': 1, 'HAT-P-56': 1, 'HAT-P-57': 1, 'HAT-P-6': 1, 'HAT-P-65': 1, 'HAT-P-66': 1, 'HAT-P-67': 1, 'HAT-P-69': 1, 'HAT-P-7': 1, 'HAT-P-70': 1, 'HAT-P-8': 1, 'HAT-P-9': 1, 'HATS-1': 1, 'HATS-10': 1, 'HATS-11': 1, 'HATS-12': 1, 'HATS-13': 1, 'HATS-14': 1, ' ...

# %%
max_solar_system = max(solar_system_planet_count, key = solar_system_planet_count.get)
print("Solar system name with the most planets: " , max_solar_system)
print("Number of planets: " , solar_system_planet_count[max_solar_system])
# Out:
# Solar system name with the most planets:  KOI-351
# Number of planets:  8

# %%
temp_planet_data_rows = list(planet_data_rows)
for planet_data in temp_planet_data_rows:
  planet_mass = planet_data[3]

  if(planet_mass.lower() == "unknown"):
    planet_data_rows.remove(planet_data)
    continue
  else:
    planet_mass_value = planet_mass.split(" ")[0]
    planet_mass_ref = planet_mass.split(" ")[1]

    if(planet_mass_ref == "Jupiters"):
      planet_mass_value = float(planet_mass_value)

    planet_data[3] = planet_mass_value


  planet_radius = planet_data[7]

  if(planet_radius.lower() == "unknown"):
    planet_data_rows.remove(planet_data)
    continue
  else:
    planet_radius_value = planet_radius.split(" ")[0]
    planet_radius_ref = planet_radius.split(" ")[2]

    if(planet_radius_ref == "Jupiter"):
      planet_radius_value = float(planet_radius_value)

    planet_data[7] = planet_radius_value

print(len(planet_data_rows))
koi_351_planets = []

for planet_data in planet_data_rows:
  if max_solar_system == planet_data[11]:
    koi_351_planets.append(planet_data)

print(len(koi_351_planets))
print(koi_351_planets)
# Out:
# 4251
# 7
# [['3665', 'Kepler-903 b', '2704', '4.7', '14.615', '2016', 'Super Earth', '2.01', 'Unknown', '10.4 days', '0', 'KOI-351', 'Transit', '89.2', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2'], ['3824', 'KOI-142 b', '1106', '9.5', '13.11', '2013', 'Neptune-like', 0.307, 'Unknown', '10.9 days', '0.06', 'KOI-351', 'Transit', '89.4', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2'], ['3825', 'KOI-142 c', '1106', 0.674, '13.11', '2013', 'Gas Giant', 1.25, '0.15525 AU', '22.3 days', '0.06', 'KOI-351', 'Transit', '89.68', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2'], ['3826', 'KOI-1599.01', '3813', '4.6', '14.854', '2019', 'Super Earth', '1.9', '0.14728 AU', '20.4 days', '0.01', 'KOI-351', 'Transit', '89.71', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2'], ['3827', 'KOI-1599.02', '3813', '9', '14.854', '2019', 'Super Earth', '1.9', '0.112293 AU', '13.6 days', '0.01', 'KOI-351', 'Transit', '89.79', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2'], ['3828', 'KOI-1783.01', '2896', 0.22339, '13.906', '2020', 'Gas Giant', 0.79, 'Unknown', '134.5 days', '0', 'KOI-351', 'Transit', '89.77', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2'], ['3829', 'KOI-1783.02', '2896', '15', '13.906', '2020', 'Neptune-like', 0.485, 'Unknown', '284.2 days', '0', 'KOI-351', 'Transit', '89.8', '', '18h57m44.04s', '+49d18m18.6s', '6080', '1.2', '1.2']]

# %%
import plotly.express as px

koi_351_planet_masses = []
koi_351_planet_names = []

for planet_data in koi_351_planets:
  koi_351_planet_masses.append(planet_data[3])
  koi_351_planet_names.append(planet_data[1])

koi_351_planet_masses.append(1)
koi_351_planet_names.append("Earth")

fig = px.bar(x = koi_351_planet_names , y = koi_351_planet_masses)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a23a1fbb-ce91-438b-b64a-874901a09fda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a23a1fbb-ce91-438b-b64a-874901a09fda")) {                    Plotly.newPlot(                        "a23a1fbb-ce91-438b-b64a-874901a09fda",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Kepler-903 b","KOI-142 b","KOI-142 c","KOI-1599.01","KOI-1599.02","KOI-1783.01","KOI-1783.02","Earth"],"xaxis":"x","y":["4.7","9.5",0.674,"4.6","9",0.22339,"15",1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"ba ...

# %%
#C132

temp_planet_data_rows = list(planet_data_rows)

for planet_data in temp_planet_data_rows:
  if planet_data[1].lower() == 'hd 100546 b':
    planet_data_rows.remove(planet_data)

planet_masses = []
planet_names = []
planet_radiuses = []

for planet_data in planet_data_rows:
  planet_masses.append(planet_data[3])
  planet_names.append(planet_data[1])
  planet_radiuses.append(planet_data[7])

planet_gravity = []

for index, name in enumerate(planet_names):
  gravity = (float(planet_masses[index]) * 5.972e+24)/(float(planet_radiuses[index]) * float(planet_radiuses[index]) * 6371000 * 6371000) * 6.674e-11
  planet_gravity.append(gravity)

fig = px.scatter(x = planet_radiuses , y = planet_masses , size = planet_gravity , hover_data = [planet_names])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bd1d66e0-fc13-41d9-bb57-e9f4468eec20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd1d66e0-fc13-41d9-bb57-e9f4468eec20")) {                    Plotly.newPlot(                        "bd1d66e0-fc13-41d9-bb57-e9f4468eec20",                        [{"customdata":[["11 Comae Berenices b"],["11 Ursae Minoris b"],["14 Andromedae b"],["14 Herculis b"],["16 Cygni B b"],["18 Delphini b"],["1RXS J160929.1-210524 b"],["24 Bootis b"],["24 Sextantis b"],["24 Sextantis c"],["2MASS J01033563-5515561 AB b"],["2MASS J01225093-2439505 b"],["2MASS J02192210-3925225 b"],["2MASS J04414489+2301513 b"],["2MASS J12073346-3932539 b"],["2MASS J19383260+4603591 b"],["2MASS J21402931+1625183 A b"],["2MASS J22362452+4751425 b"],["30 Arietis B b"],["42 Draconis b"],["47 Ursae Majoris b"],["47 Ursae Majoris c"],["47 Ursae Majoris d"],["4 Ursae Majoris b"],["51 Eridani b"],["51 Pegasi b"],["55 Cancri b"],["55 Cancri c"],["55 Cancri d"],["55 Cancri e"],["55 Cancri f"],["61 Virginis b"],["61 Virginis c"],["61 Virginis d"],["6 Lyncis b"],["70 Virginis b"],["75 Ceti b"],["7 Canis Majoris b"],["7 Canis Majoris c"],["81 Ceti b"],["8 Ursae Minoris b"],["91 Aquarii b"],["AB Pictoris b"],["Alpha Arietis b"],["Alpha Tauri b"],["AU Microscopii b"],["BD+03 2562 b"],["BD-06 1339 b"],["BD-06 1339 c"],["BD-08 2823 b"],["BD-08 2823 c"],["BD-10 3166 b"],["BD-11 4672 b"],["BD-11 4672 c"],["BD-13 2130 b"],["BD+14 4559 b"],["BD+15 2375 b"],["BD+15 2940 b"],["BD-17 63 b"],["BD+20 2457 b"],["BD+20 2457 c"],["BD+20 274 b"],["BD+20 594 b"],["BD+48 738 b"],["BD+48 740 b"],["BD+49 828 b"],["Beta Cancri b"],["Beta Pictoris b"],["Beta Pictoris c"],["Beta Ursae Minoris b"],["CFBDSIR J145829+101343 b"],["CHXR 73 b"],["CI Tauri b"],["CoRoT-10 b"],["CoRoT-11 b"],["CoRoT-12 b"],["CoRoT-13 b"],["CoRoT-14 b"],["CoRoT-16 b"],["CoRoT-17 b"],["CoRoT-18 b"],["CoRoT-19 b"],["CoRoT-1 b"],["CoRoT-20 b"],["CoRoT-20 c"],["CoRoT-21 b"],["CoRoT-22 b"],["CoRoT-23 b"],["CoRoT-24 b"],["CoRoT-24 c"],["CoRoT-25 b"],["CoRoT-26 b"],["CoRoT-27 b"],["CoRoT-28 b"],["CoRoT-29 b"],["CoRoT-2 b"],["CoRoT-30 b"],["CoRoT-31 b"],["CoRoT-3 b"],["CoRoT-4 b"],["CoRoT-5 b"],["CoRoT-6 b"],["CoRoT-7 b"],["CoRoT-7 c"],["CoRoT-8 b"],["CoRoT-9 b"],["CoRoTID 223977153 b"],["CT Chamaleontis b"],["DE Canun Venaticorum b"],["DENIS-P J082303.1-491201 b"],["DH Tauri b"],["DMPP-1 b"],["DMPP-1 c"],["DMPP-1 d"],["DMPP-1 e"],["DMPP-2 b"],["DMPP-3 A b"],["DP Leonis b"],["DS Tucanae A b"],["EPIC 201238110 b"],["EPIC 201497682 b"],["EPIC 201615463 c"],["EPIC 201754305 d"],["EPIC 201833600 c"],["EPIC 201841433 b"],["EPIC 205950854 c"],["EPIC 206024342 b"],["EPIC 206032309 b"],["EPIC 206042996 b"],["EPIC 206215704 b"],["EPIC 206317286 b"],["EPIC 211822797 b"],["EPIC 211945201 b"],["EPIC 212297394 b"],["EPIC 212424622 b"],["EPIC 212499991 b"],["EPIC 212587672 b"],["EPIC 212737443 b"],["EPIC 212737443 c"],["EPIC 220554210 c"],["EPIC 220674823 b"],["EPIC 220674823 c"],["EPIC 246851721 b"],["EPIC 248847494 b"],["EPIC 249893012 b"],["EPIC 249893012 c"],["EPIC 249893012 d"],["Epsilon Coronae Borealis b"],["Epsilon Eridani b"],["Epsilon Indi A b"],["Epsilon Tauri b"],["FU Tauri b"],["G 9-40 b"],["Gamma 1 Leonis b"],["Gamma Cephei b"],["Gamma Librae b"],["Gamma Librae c"],["GJ 1061 b"],["GJ 1061 c"],["GJ 1061 d"],["GJ 1132 b"],["GJ 1132 c"],["GJ 1148 b"],["GJ 1148 c"],["GJ 1214 b"],["GJ 1252 b"],["GJ 1265 b"],["GJ 143 b"],["GJ 15 A b"],["GJ 15 A c"],["GJ 160.2 b"],["GJ 163 b"],["GJ 163 c"],["GJ 163 d"],["GJ 179 b"],["GJ 180 b"],["GJ 180 c"],["GJ 180 d"],["GJ 2056 b"],["GJ 229 A c"],["GJ 229 b"],["GJ 27.1 b"],["GJ 273 b"],["GJ 273 c"],["GJ 3021 b"],["GJ 3082 b"],["GJ 3138 b"],["GJ 3138 c"],["GJ 3138 d"],["GJ 317 b"],["GJ 317 c"],["GJ 328 b" ...

# %%
#Gavity  <=100

low_gravity_planets = []

for index, gravity in enumerate(planet_gravity):
  if(gravity < 100):
    low_gravity_planets.append(planet_data_rows[index])

print(len(low_gravity_planets))
# Out:
# 2800

# %%
print(headers)
# Out:
# ['id', 'name', 'light_years_from_earth', 'planet_mass', 'stellar_magnitude', 'discovery_date', 'planet_type', 'planet_radius', 'orbital_radius', 'orbital_period', 'eccentricity', 'solar_system_name', 'planet_discovery_method', 'planet_orbital_inclination', 'planet_density', 'right_ascension', 'declination', 'host_temperature', 'host_mass', 'host_radius']

# %%
planet_type_values = []

for planet_data in planet_data_rows:
  planet_type_values.append(planet_data[6])

print(list(set(planet_type_values)))
# Out:
# ['Super Earth', 'Terrestrial', 'Gas Giant', 'Neptune-like']

# %%
planet_masses = []
planet_radiuses = []
for planet_data in low_gravity_planets:
  planet_masses.append(planet_data[3])
  planet_radiuses.append(planet_data[7])

fig = px.scatter(x  = planet_radiuses , y = planet_masses)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70ecb7ce-ecd0-4aaa-a1ec-6f57a5ccb03e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70ecb7ce-ecd0-4aaa-a1ec-6f57a5ccb03e")) {                    Plotly.newPlot(                        "70ecb7ce-ecd0-4aaa-a1ec-6f57a5ccb03e",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1.15,1.15,1.2,1.11,1.664,1.24,1.19,1.24,1.44,1.13,1.16,1.2,1.16,1.18,1.27,1.2,1.13,1.19,1.27,1.24,0.76,1.16,"1.91",0.677,"2.11",1.19,1.13,1.17,1.2,1.24,1.14,1.22,1.17,1.2,1.13,0.375,1.13,0.747,1.11,1.26,1.25,1.11,1.23,1.23,1.23,1.15,1.16,1.24,1.2,1.21,1.12,1.65,1.12,1.14,1.11,1.11,0.97,1.43,1.44,0.885,1.09,1.17,1.02,1.31,1.29,1.49,0.84,1.3,1.05,1.08,1.26,0.955,0.9,1.466,1.009,1.46,1.19,1.388,1.166,"1.681",0.57,1.066,0.57,2.2,1.1,2.7,"1.65","1.86",1.28,"1.41",1.14,0.509,"1.87","0.692","1.22","1.03","1.0","1.1","1.31","1.7","1.01","1.62","0.9","0.96","1.98","1.323","2.17","1.6","1.12","1.48","1.82",1.051,"1.95",1.13,1.24,1.17,1.13,"2.025",1.12,1.2,1.23,1.15,"1.1","1.18","1.16","1.13","1.43",1.07,0.866,"1.193","1.55",1.24,"1.51","1.06",1.17,"1.18","1.88",1.18,1.2,1.19,"1.63","1.23","1.32",1.27,"1.217","1.66","1.38","1.54","2.14",1.16,"2.17","2.21","1.17","1.49",1.11,"2.23","1.77","1.45","1.45","1.99",1.13,1.13,"1.93","1.93",1.25,"2.18",1.23,1.15,1.19,1.25,"1.88",0.892,"1.577","1.241","2.022",3.0,1.8,1.265,1.19,0.959,1.272,1.42,1.06,1.289,1.05,1.17,0.995,1.132,1.319,0.867,1.11,1.15,1.09,1.3,1.135,1.02,1.212,1.17,0.951,1.44,1.09,1.98,1.85,1.197,1.332,1.277,1.178,0.825,1.571,0.94,1.52,2.05,1.28,1.281,1.242,1.16,1.426,1.284,1.59,1.274,1.288,1.293,1.009,1.318,0.944,1.182,1.51,1.74,1.21,1.89,1.59,2.085,1.676,1.48,1.87,1.51,1.4,1.393,0.969,1.609,0.692,1.212,1.039,1.105,1.3,0.777,1.329,1.302,0.953,1.86,1.395,1.26,1.75,1.5,1.194,1.251,1.168,1.175,1.64,1.249,1.23,1.43,1.464,1.153,1.57,1.381,1.58,1.33,1.4,1.18,1.067,1.286,0.903,1.117,0.8,0.765,1.02,1.13,1.41,1.382,1.34,1.067,1.251,1.688,1.139,1.095,1.126,0.912,1.153,1.195,1.055,1.207,1.679,1.501,1.411,1.685,1.232,0.945,0.998,1.384,1.024,0.873,1.236,1.21,1.23,0.848,0.949,0.756,1.27,1.15,1.12,1.21,1.17,1.23,1.26,1.19,0.729,1.21,1.12,1.13,1.11,1.23,1.11,1.11,1.13,0.856,0.973,1.17,1.18,1.21,1.23,1.24,0.993,1.11,1.13,1.15,1.15,1.18,1.18,1.24,1.14,1.22,1.17,1.24,1.11,1.23,1.26,1.15,1.27,1.21,1.22,1.2,1.14,0.766,1.18,1.26,1.13,1.15,1.21,1.17,1.17,1.13,1.2,0.919,1.27,1.18,1.2,1.2,1.16,1.24,1.21,1.22,1.2,1.17,1.11,1.14,1.21,1.21,1.28,1.18,1.21,1.24,"2.04",1.19,0.832,1.24,1.15,1.19,1.11,1.026,1.12,1.28,1.22,1.22,1.25,1.11,1.15,1.17,1.2,1.22,1.14,1.22,1.16,1.14,1.19,1.19,"2.23",1.19,1.13,1.22,1.15,1.19,1.23,1.24,1.22,1.15,1.22,0.74,1.22,1.18,1.18,1.18,1.2,"1.64",1.17,1.24,1.14,1.18,1.18,1.18,1.23,1.24,1.11,1.12,1.25,"1.87",1.11,1.21,"1.29","2.23","2.18",1.22,1.2,1.19,1.25,1.23,1.16,1.2,1.2,1.27,0.971,1.15,1.11,1.24,1.19,1.28,1.19,1.19,"1.83",1.18,1.13,1.16,1.2,1.13,0.993,1.12,1.18,1.16,1.25,1.11,1.18,1.18,1.1,1.18,1.12,1.26,1.24,1.2,0.702,1.12,1.24,1.19,1.17,1.2,1.12,1.18,1.26,1.27,1.25,1.16,1.16,1.23,1.24,1.27,1.19,1.17,1.21,1.13,1.21,1.19,1.17,1.12,1.26,1.19,1.16,1.17,1.13,1.18,1.24,1.21,1.21,1.22,1.545,1.12,1.14,1.17,0.903,1.21,1.19,"1.21","2.17",1.21,1.26,1.25,"1.45","1.35","2.04","2.03",1.27,1.11,1.22,1.21,1.39,1.27,1.22,1.2,1.25,1.27,1.18,1.14,"1.745",0.85,"1.19","1.17","1.48","1.51",1.11,1.22,1.19,1.23,1.26,1.22,1.18,"0.892",0.832,1.11,"1.602","1.511","1.61","1.31",1.14,1.23,0.832,1.23,1.21,1.17,1.17,0.836,1.11,1.21,1.21,1.19,1.12,1.14,1.25,1.18,1.21,1.22,1.13,1.2,1.12,1.14,1.14,1.16,1.15,1.24,1.28,1.44,1.21,1.21,1.25,0.735,1.14,1.14,1.22,1.23, ...

# %%
planet_types = []
for planet_data in low_gravity_planets:
  planet_types.append(planet_data[6])

fig = px.scatter(x = planet_radiuses , y = planet_masses , color = planet_types)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dd3d5ba6-b8d0-4386-b9cd-d41bf4c5714a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd3d5ba6-b8d0-4386-b9cd-d41bf4c5714a")) {                    Plotly.newPlot(                        "dd3d5ba6-b8d0-4386-b9cd-d41bf4c5714a",                        [{"hovertemplate":"color=Gas Giant\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas Giant","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gas Giant","showlegend":true,"x":[1.15,1.15,1.2,1.11,1.664,1.24,1.19,1.24,1.44,1.13,1.16,1.2,1.16,1.18,1.27,1.2,1.13,1.19,1.27,1.24,0.76,1.16,0.677,1.19,1.13,1.17,1.2,1.24,1.14,1.22,1.17,1.2,1.13,0.375,1.13,0.747,1.11,1.26,1.25,1.11,1.23,1.23,1.23,1.15,1.16,1.24,1.2,1.21,1.12,1.65,1.12,1.14,1.11,1.11,0.97,1.43,1.44,0.885,1.09,1.17,1.02,1.31,1.29,1.49,0.84,1.3,1.05,1.08,1.26,0.955,0.9,1.466,1.009,1.46,1.19,1.388,1.166,0.57,1.066,0.57,2.2,1.1,2.7,1.28,1.14,1.051,1.13,1.24,1.17,1.13,1.12,1.2,1.23,1.15,1.07,0.866,1.24,1.17,1.18,1.2,1.19,1.27,1.16,1.11,1.13,1.13,1.25,1.23,1.15,1.19,1.25,0.892,3.0,1.8,1.265,1.19,0.959,1.272,1.42,1.06,1.289,1.05,1.17,0.995,1.132,1.319,0.867,1.11,1.15,1.09,1.3,1.135,1.02,1.212,1.17,0.951,1.44,1.09,1.98,1.85,1.197,1.332,1.277,1.178,0.825,1.571,0.94,1.52,2.05,1.28,1.281,1.242,1.16,1.426,1.284,1.59,1.274,1.288,1.293,1.009,1.318,0.944,1.182,1.51,1.74,1.21,1.89,1.59,2.085,1.676,1.48,1.87,1.51,1.4,1.393,0.969,1.609,0.692,1.212,1.039,1.105,1.3,0.777,1.329,1.302,0.953,1.86,1.395,1.26,1.75,1.5,1.194,1.251,1.168,1.175,1.64,1.249,1.23,1.43,1.464,1.153,1.57,1.381,1.58,1.33,1.4,1.18,1.067,1.286,0.903,1.117,0.8,0.765,1.02,1.13,1.41,1.382,1.34,1.067,1.251,1.688,1.139,1.095,1.126,0.912,1.153,1.195,1.055,1.207,1.679,1.501,1.411,1.685,1.232,0.945,0.998,1.384,1.024,0.873,1.236,1.21,1.23,0.848,0.949,0.756,1.27,1.15,1.12,1.21,1.17,1.23,1.26,1.19,0.729,1.21,1.12,1.13,1.11,1.23,1.11,1.11,1.13,0.856,0.973,1.17,1.18,1.21,1.23,1.24,0.993,1.11,1.13,1.15,1.15,1.18,1.18,1.24,1.14,1.22,1.17,1.24,1.11,1.23,1.26,1.15,1.27,1.21,1.22,1.2,1.14,0.766,1.18,1.26,1.13,1.15,1.21,1.17,1.17,1.13,1.2,0.919,1.27,1.18,1.2,1.2,1.16,1.24,1.21,1.22,1.2,1.17,1.11,1.14,1.21,1.21,1.28,1.18,1.21,1.24,1.19,0.832,1.24,1.15,1.19,1.11,1.026,1.12,1.28,1.22,1.22,1.25,1.11,1.15,1.17,1.2,1.22,1.14,1.22,1.16,1.14,1.19,1.19,1.19,1.13,1.22,1.15,1.19,1.23,1.24,1.22,1.15,1.22,0.74,1.22,1.18,1.18,1.18,1.2,1.17,1.24,1.14,1.18,1.18,1.18,1.23,1.24,1.11,1.12,1.25,1.11,1.21,1.22,1.2,1.19,1.25,1.23,1.16,1.2,1.2,1.27,0.971,1.15,1.11,1.24,1.19,1.28,1.19,1.19,1.18,1.13,1.16,1.2,1.13,0.993,1.12,1.18,1.16,1.25,1.11,1.18,1.18,1.1,1.18,1.12,1.26,1.24,1.2,0.702,1.12,1.24,1.19,1.17,1.2,1.12,1.18,1.26,1.27,1.25,1.16,1.16,1.23,1.24,1.27,1.19,1.17,1.21,1.13,1.21,1.19,1.17,1.12,1.26,1.19,1.16,1.17,1.13,1.18,1.24,1.21,1.21,1.22,1.545,1.12,1.14,1.17,0.903,1.21,1.19,1.21,1.26,1.25,1.27,1.11,1.22,1.21,1.39,1.27,1.22,1.2,1.25,1.27,1.18,1.14,0.85,1.11,1.22,1.19,1.23,1.26,1.22,1.18,0.832,1.11,1.14,1.23,0.832,1.23,1.21,1.17,1.17,0.836,1.11,1.21,1.21,1.19,1.12,1.14,1.25,1.18,1.21,1.22,1.13,1.2,1.12,1.14,1.14,1.16,1.15,1.24,1.28,1.44,1.21,1.21,1.25,0.735,1.14,1.14,1.22,1.23,1.21,1.18,1.18,1.21,1.12,1.13,1.22,1.27,1.21,1.26,1.17,1.25,1.27,1.21,1.14,0.867,1.12,1.12,1.19,1.2,1.24,0.752,1.21,1.16,0.899,1.25,1.25,1.25,1.18,1.17,1.25,1.24,1.11,1.18,1.15,1.18,1.21,1.21,1.19,1.19,1.24,1.2,1.26,1.18,1.26,1.2,0.8,1.25,1.28,0.894,1.16,1.19,1.19,1.19,1.2,1.13,1.21,1.21,1.2,1.17,1.15,1.22,1.21,1.23,1.16,1.14,1.2,1.12,1.13,1.13,1.23,1.18,1.19,1.098,1.27,1.27,1.22,1.19,1.14,1.17,1.17,1.15,1.2,1.17,1.2,1.14,1.19,0.993,1.2,1.16,1.14,1.17,1.17,1.19,1.23,1.2,1.12,1.27,1.27,1.23,1.14,1.18,0.856,1.16,1.22,1.07,1.13,1.18,1.19,1.2,1.2,0.855,1.14,1.25,1.19 ...

# %%
suitable_planets = []

for planet_data in low_gravity_planets:
  if planet_data[6].lower() == "super earth" or planet_data[6].lower() == "terrestrial":
      suitable_planets.append(planet_data)

print(len(suitable_planets))
# Out:
# 1426

# %%
#C133

print(headers)
# Out:
# ['id', 'name', 'light_years_from_earth', 'planet_mass', 'stellar_magnitude', 'discovery_date', 'planet_type', 'planet_radius', 'orbital_radius', 'orbital_period', 'eccentricity', 'solar_system_name', 'planet_discovery_method', 'planet_orbital_inclination', 'planet_density', 'right_ascension', 'declination', 'host_temperature', 'host_mass', 'host_radius']

# %%
temp_suitable_planets = list(suitable_planets)

for planet_data in temp_suitable_planets:
  if planet_data[8].lower() == "unknown":
    suitable_planets.remove(planet_data)

for planet_data in suitable_planets:
  if planet_data[9].split(" ")[1].lower() == "days":
    planet_data[9] = float(planet_data[9].split(" ")[0])
  else:
    planet_data[9] = float(planet_data[9].split(" ")[0]) * 365

  planet_data[8] = float(planet_data[8].split(" ")[0])

orbital_radiuses = []
orbital_periods = []

for planet_data in suitable_planets:
  orbital_radiuses.append(planet_data[8])
  orbital_periods.append(planet_data[9])

fig = px.scatter(x = orbital_radiuses ,  y = orbital_periods)
fig.show() #Goldilock planets
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09f6c94a-de01-498c-b814-680d5a709e7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09f6c94a-de01-498c-b814-680d5a709e7e")) {                    Plotly.newPlot(                        "09f6c94a-de01-498c-b814-680d5a709e7e",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.01544,0.017016,0.0422,0.0651,0.0662,0.131,0.0134,0.047,0.0385,0.021,0.035,0.054,0.0153,0.0476,0.00916,0.072,0.091101,0.036467,0.0197,0.057,0.08208,0.03282,0.1264,0.035,0.061,0.029,0.0785,0.02815,0.078361,0.125,0.213,0.156,0.549,0.0413,0.08,0.068,0.0188,0.03925,0.0934,0.0522,0.05,0.103,0.0529,0.1207,0.2036,0.3499,0.509,0.02012,0.057638,0.067393,0.08799,0.15417,0.0695,0.03876,0.0653,0.237,0.1463,0.0186,0.0468,0.0166,0.26,0.049,0.048,0.0674,0.023,0.0621,0.048,0.0189,0.0492,0.078,0.0285,0.0656,0.056,0.057,0.032,0.0095,0.03194,0.04341,0.07487,0.1346,0.0058,0.0338,0.2114,0.00716,0.0259,0.0159,0.0454,0.0616,0.0774,0.083,0.0727,0.0373,0.0614,0.0405,0.0677,0.0562,0.1937,0.0149,0.0622,0.1937,0.0149,0.0622,0.0667,0.1229,0.0164,0.0392,0.0289,0.0361,0.049,0.0385,0.028,0.0127,0.0549,0.0516,0.0413,0.0338,0.0131,0.0769,0.0127,0.0549,0.0516,0.0413,0.0338,0.0131,0.0769,0.0576,0.0685,0.0513,0.1159,0.1817,0.1418,0.1041,0.0448,0.0216,0.03376,0.0679,0.0308,0.0531,0.0247,0.0675,0.067,0.164,0.03261,0.0147,0.0582,0.0911,0.041,0.0594,0.04951,0.055,0.031,0.0223,0.0511,0.05073,0.074,0.1345,0.2097,0.13821,0.1779,0.0309,0.0705,0.0671,0.035,0.1517,0.0532,0.0619,0.1014,0.0708,0.04,0.078,0.05,0.106,0.135,0.0596,0.059,0.03014,0.07131,0.1768,0.01263,0.077,0.0345,0.01462,0.035,0.0164,0.0684,0.0731,0.04544,0.06064,0.08377,0.0172,0.107,0.046,0.053,0.06482,0.036,0.073,0.049,0.091,0.055,0.088,0.3006,0.181,0.039,0.1,0.17,0.051,0.099,0.162,0.125,0.1264,0.1664,0.079,0.377,0.067,0.068,0.136,0.083,0.06,0.092,0.067,0.103,0.106,0.133,0.077,0.13,0.076,0.0906,0.12781,0.045,0.414,0.2543,0.039,0.067,0.032,0.066,0.094,0.113,0.028,0.281,0.044,0.1097,0.16,0.5421,0.056,0.028,0.158,0.6421,0.05511,0.054,0.068,0.069,0.745,0.078,0.0514,0.058,0.1654,0.0483,0.0684,0.1405,0.056,0.04,0.062,0.075,0.223,0.048,0.1,0.214,0.058,0.036,0.064,0.109,0.04,0.049,0.064,0.141,0.026,0.139,0.0343,0.0451,0.0781,0.11,0.432,0.059,0.032,0.088,0.0447,0.03,0.045,0.087,0.128,0.032,0.077,0.197,0.138,0.06,0.09,0.119,0.164,0.09,0.045,0.113,0.173,0.032,0.122,0.078,0.111,0.163,0.029,0.044,0.054,0.079,0.103,0.132,0.0463,0.0639,0.048,0.133,0.036,0.084,0.113,0.314,0.089,0.046,0.042717,0.046,0.076,0.163,0.226,0.037,0.038,0.124,0.056,0.111,0.047,0.058,0.076,0.038,0.38,0.114,0.065,0.122,0.065,0.132,0.05,0.071,0.034,0.124,0.048,0.074,0.109,0.142,0.087,0.124,0.095,0.042,0.035,0.058,0.097,0.051,0.048,0.053,0.058,0.046,0.063,0.027,0.075,0.332,0.156,0.108,0.152,0.069,0.037,0.081,0.039,0.107,0.18,0.056,0.071,0.038,0.061,0.037,0.073,0.101,0.204,0.032,0.056,0.082,0.106,0.341,0.036,0.064,0.027,0.042,0.061,0.176,0.065,0.21,0.065,0.035,0.045,0.048,0.099,0.142,0.192,0.079,0.169,0.255,0.08,0.136,0.04,0.118,0.22,0.094,0.036,0.06,0.112,0.024,0.057,0.05,0.059,0.111,0.087,0.145,0.031,0.035,0.027,0.058,0.061,0.083,0.051,0.085,0.142,0.057,0.027,0.051,0.028,0.046,0.05,0.032,0.051,0.066,0.029,0.09,0.061,0.113,0.033,0.013,0.075,0.116,0.065,0.105,0.159,0.07,0.114,0.189,0.135,0.061,0.107,0.168,0.033,0.045,0.093,0.055,0.069,0.0677,0.1189,0.06,0.08,0.182,0.242,0.185,0.167,0.066,0.077,0.11,0.183,0.076,0.138,0.065,0.105,0.104,0.085,0.118,0.051,0.065,0.054,0.115,0.146,0.102,0.057,0.115,0.063,0.044,0.086,0.087,0.207,0.048,0.079,0.107,0.178,0.098,0.137,0.045,0.11,0.201,0.253,0.03,0 ...

# %%
goldilock_planets = list(suitable_planets)
temp_goldilock_planets = list(suitable_planets)

for planet_data in temp_goldilock_planets:
  if planet_data[8] < 0.38 or planet_data[8] > 2:
    goldilock_planets.remove(planet_data)

print(len(suitable_planets))
print(len(goldilock_planets))
# Out:
# 676
# 23

# %%
planet_speeds = []

for planet_data in suitable_planets:
  distance = 2 * 3.14 * (planet_data[8] * 1.496e+8)
  time = planet_data[9] * 86400
  speed = distance / time

  planet_speeds.append(speed)

speed_supporting_planets = list(suitable_planets)
temp_speed_supporting_planets = list(suitable_planets)

for index , planet_data in enumerate(temp_speed_supporting_planets):
  if planet_speeds[index] > 200:
    speed_supporting_planets.remove(planet_data)

print(len(speed_supporting_planets))
# Out:
# 655

# %%
#C134

habitable_planets = []
for planet in speed_supporting_planets:
  if planet in goldilock_planets:
    habitable_planets.append(planet)

print(len(habitable_planets))
# Out:
# 23

# %%
final_dict = {}
for index , planet_data in enumerate(planet_data_rows):
  features_list = []
  gravity = (float(planet_data[3]) * 5.972e+24) / (float(planet_data[7]) * float(planet_data[7]) * 6371000 * 6371000) * 6.674e-11
  try:
    if gravity < 100:
      features_list.append("gravity")
  except: pass

  try:
    if planet_data[6].lower() == "terrestrial" or planet_data[6].lower() == "super earth":
      features_list.append("planet_type")
  except:pass

  try:
    if planet_data[8] > 0.38 or planet_data[8] < 2:
      features_list.append("goldilock")
  except: pass

  try:
    distance = 2 * 3.14 * (planet_data[8] * 1.496e+8)
    time = planet_data[9] * 86400
    speed = distance / time
    if speed < 200:
      features_list.append("speed")
  except: pass

  final_dict[index] = features_list

print(final_dict)
# Out:
# {0: [], 1: [], 2: ['gravity'], 3: ['gravity'], 4: ['gravity'], 5: ['gravity'], 6: ['gravity'], 7: ['gravity'], 8: ['gravity'], 9: ['gravity'], 10: [], 11: [], 12: ['gravity'], 13: ['gravity'], 14: ['gravity'], 15: ['gravity'], 16: [], 17: [], 18: [], 19: ['gravity'], 20: ['gravity'], 21: ['gravity'], 22: ['gravity'], 23: ['gravity'], 24: ['gravity'], 25: ['gravity'], 26: ['gravity'], 27: ['gravity'], 28: ['gravity'], 29: ['gravity', 'planet_type', 'goldilock'], 30: ['gravity'], 31: ['gravity'], 32: [], 33: [], 34: ['gravity'], 35: ['gravity'], 36: ['gravity'], 37: ['gravity'], 38: ['gravity'], 39: ['gravity'], 40: ['gravity'], 41: ['gravity'], 42: [], 43: ['gravity'], 44: ['gravity'], 45: ['gravity'], 46: ['gravity'], 47: [], 48: ['gravity'], 49: [], 50: ['gravity'], 51: ['gravity'], 52: ['gravity'], 53: [], 54: ['gravity'], 55: ['gravity'], 56: ['gravity'], 57: ['gravity'], 58: ['gravity'], 59: [], 60: [], 61: ['gravity'], 62: [], 63: ['gravity'], 64: ['gravity'], 65: ['gravity'], 66: ['gravity'], 67: ['gravity'], 68: ['gravity'], 69: ['gravity'], 70: ['gravity'], 71: [], 72: ['gravity'], 73: ['gravity'], 74: ['gravity'], 75: ['gravity'], 76: ['gravity'], 77: ['gravity'], 78: ['gravity'], 79: ['gravity'], 80: ['gravity'], 81: ['gravity'], 82: ['gravity'], 83: ['gravity'], 84: [], 85: ['gravity'], 86: [], 87: ['gravity'], 88: [], 89: [], 90: ['gravity'], 91: ['gravity'], 92: [], 93: ['gravity'], 94: ['gravity'], 95: ['gravity'], 96: ['gravity'], 97: ['gravity'], 98: [], 99: ['gravity'], 100: ['gravity'], 101: ['gravity'], 102: ['gravity', 'planet_type', 'goldilock'], 103: [], 104: ['gravity'], 105: ['gravity'], 106: ['gravity'], 107: ['gravity'], 108: ['gravity'], 109: [], 110: ['gravity'], 111: [], 112: [], 113: ['gravity', 'planet_type', 'goldilock', 'speed'], 114: ['gravity', 'planet_type', 'goldilock', 'speed'], 115: ['gravity'], 116: ['gravity', 'planet_type', 'goldilock', 'speed'], 117: ['gravity'], 118: ['gravity'], 119: ['gravity', 'planet_type'], 120: ['gravity', 'planet_type'], 121: ['gravity', 'planet_type'], 122: ['gravity', 'planet_type'], 123: ['gravity', 'planet_type'], 124: ['gravity', 'planet_type'], 125: ['gravity', 'planet_type'], 126: ['gravity', 'planet_type'], 127: ['gravity', 'planet_type'], 128: ['gravity', 'planet_type'], 129: ['gravity', 'planet_type'], 130: ['gravity', 'planet_type'], 131: ['gravity', 'planet_type', 'goldilock', 'speed'], 132: [], 133: ['gravity', 'planet_type'], 134: ['gravity'], 135: ['gravity', 'planet_type'], 136: ['gravity', 'planet_type'], 137: [], 138: [], 139: ['gravity', 'planet_type'], 140: ['gravity', 'planet_type', 'goldilock'], 141: [], 142: ['gravity'], 143: [], 144: ['gravity', 'planet_type', 'goldilock', 'speed'], 145: [], 146: [], 147: ['gravity'], 148: ['gravity'], 149: ['gravity'], 150: ['gravity'], 151: [], 152: ['gravity', 'planet_type', 'goldilock', 'speed'], 153: ['gravity'], 154: ['gravity'], 155: ['gravity'], 156: ['gravity'], 157: ['gravity', 'planet_type', 'goldilock', 'speed'], 158: ['gravity', 'planet_type', 'goldilock', 'speed'], 159: ['gravity', 'planet_type', 'goldilock', 'speed'], 160: ['gravity', 'planet_type', 'goldilock', 'speed'], 161: ['gravity', 'planet_type', 'goldilock', 'speed'], 162: ['gravity'], 163: ['gravity'], 164: [], 165: ['gravity', 'planet_type', 'goldilock', 'speed'], 166: [], 167: [], 168: ['gravity', 'planet_type', 'goldilock', 'speed'], 169: [], 170: [], 171: [], 172: [], 173: [], 174: ['gravity'], 175: [], 176: [], 177: [], 178: [], 179: [], 180: [], 181: [], 182: ['gravity', 'planet_type', 'goldilock', 'speed'], 183: ['gravity', 'planet_type', 'goldilock', 'speed'], 184: ['gravity'], 185: [], 186: ['gravity', 'planet_type', 'goldilock', 'speed'], 187: ['gravity', 'planet_type', 'goldilock', 'speed'], 188: [], 189: ['gravity'], 190: ['gravity'], 191: ['gravity'], 192: [], 193: [], 194: [], 195: ['gravity', 'planet_type', 'goldilock', 'speed'], 196: ['gravity', 'planet_type', 'goldilock', 'speed'], 197: ['gravity', 'planet_type', ...

# %%
goldilock_planet_count = 0

for key , value in final_dict.items():
  if "goldilock" in value:
    goldilock_planet_count += 1

print(goldilock_planet_count)
# Out:
# 676

# %%
speed_planet_count = 0

for key , value in final_dict.items():
  if "speed" in value:
    speed_planet_count += 1

print(speed_planet_count)
# Out:
# 655

# %%
gravity_planet_count = 0

for key , value in final_dict.items():
  if "gravity" in value:
    gravity_planet_count += 1

print(gravity_planet_count)
# Out:
# 2800

# %%
planet_type_planet_count = 0

for key , value in final_dict.items():
  if "planet_type" in value:
    planet_type_planet_count += 1

print(planet_type_planet_count)
# Out:
# 1485

# %%
#C135

gravity_planet_count = 0

for key , value in final_dict.items():
  if "gravity" in value:
    gravity_planet_count +=1

print(gravity_planet_count)
# Out:
# 2800

# %%
planet_type_planet_count = 0

for key , value in final_dict.items():
  if "planet_type" in value:
    planet_type_planet_count+= 1

print(planet_type_planet_count)
# Out:
# 1485

# %%
planet_not_gravity_support = []

for planet_data in planet_data_rows:
  if planet_data not in low_gravity_planets:
    planet_not_gravity_support.append(planet_data)

type_no_gravity_planet_count = 0

for planet_data in planet_not_gravity_support:
  if planet_data[6].lower() == 'terrestrial' or planet_data[6].lower() == "super earth":
    type_no_gravity_planet_count += 1

print(type_no_gravity_planet_count)
print(planet_type_planet_count - type_no_gravity_planet_count)
# Out:
# 59
# 1426

# %%
goldilock_planet_count = 0
for key,value in final_dict.items():
  if "goldilock" in value:
    goldilock_planet_count += 1

print(goldilock_planet_count)
# Out:
# 676

# %%
speed_planet_count = 0

for key,value in final_dict.items():
  if "speed" in value:
    speed_planet_count += 1

print(speed_planet_count)
# Out:
# 655

# %%
final_dict = {}
for index , planet_data in enumerate(planet_data_rows):
  features_list = []
  gravity = (float(planet_data[3]) * 5.972e+24) / (float(planet_data[7]) * float(planet_data[7]) * 6371000 * 6371000) * 6.674e-11
  try:
    if gravity < 100:
      features_list.append("gravity")
  except: pass

  try:
    if planet_data[6].lower() == "terrestrial" or planet_data[6].lower() == "super earth":
      features_list.append("planet_type")
  except:pass

  try:
    if float(planet_data[8].split(" ")[0]) > 0.38 and float(planet_data[8].split(" ")[0]) < 2:
      features_list.append("goldilock")
  except:
    try:
      if planet_data[8] > 0.38 and planet_data[8] < 2:
        features_list.append("goldilock")
    except: pass

  try:
    distance = 2 * 3.14 * (planet_data[8] * 1.496e+8)
    time = planet_data[9] * 86400
    speed = distance / time
    if speed < 200:
      features_list.append("speed")
  except: pass

  final_dict[index] = features_list

print(final_dict)
# Out:
# {0: ['goldilock'], 1: ['goldilock'], 2: ['gravity', 'goldilock'], 3: ['gravity'], 4: ['gravity', 'goldilock'], 5: ['gravity'], 6: ['gravity'], 7: ['gravity'], 8: ['gravity', 'goldilock'], 9: ['gravity'], 10: [], 11: [], 12: ['gravity'], 13: ['gravity'], 14: ['gravity'], 15: ['gravity', 'goldilock'], 16: [], 17: [], 18: ['goldilock'], 19: ['gravity', 'goldilock'], 20: ['gravity'], 21: ['gravity'], 22: ['gravity'], 23: ['gravity', 'goldilock'], 24: ['gravity'], 25: ['gravity'], 26: ['gravity'], 27: ['gravity'], 28: ['gravity'], 29: ['gravity', 'planet_type'], 30: ['gravity', 'goldilock'], 31: ['gravity'], 32: [], 33: ['goldilock'], 34: ['gravity'], 35: ['gravity', 'goldilock'], 36: ['gravity'], 37: ['gravity', 'goldilock'], 38: ['gravity'], 39: ['gravity'], 40: ['gravity', 'goldilock'], 41: ['gravity', 'goldilock'], 42: [], 43: ['gravity', 'goldilock'], 44: ['gravity', 'goldilock'], 45: ['gravity'], 46: ['gravity', 'goldilock'], 47: [], 48: ['gravity', 'goldilock'], 49: [], 50: ['gravity', 'goldilock'], 51: ['gravity'], 52: ['gravity'], 53: [], 54: ['gravity', 'goldilock'], 55: ['gravity', 'goldilock'], 56: ['gravity', 'goldilock'], 57: ['gravity', 'goldilock'], 58: ['gravity', 'goldilock'], 59: ['goldilock'], 60: [], 61: ['gravity', 'goldilock'], 62: [], 63: ['gravity', 'goldilock'], 64: ['gravity', 'goldilock'], 65: ['gravity'], 66: ['gravity', 'goldilock'], 67: ['gravity'], 68: ['gravity'], 69: ['gravity', 'goldilock'], 70: ['gravity'], 71: [], 72: ['gravity'], 73: ['gravity'], 74: ['gravity'], 75: ['gravity'], 76: ['gravity'], 77: ['gravity'], 78: ['gravity'], 79: ['gravity'], 80: ['gravity'], 81: ['gravity'], 82: ['gravity'], 83: ['gravity'], 84: [], 85: ['gravity'], 86: [], 87: ['gravity'], 88: [], 89: [], 90: ['gravity'], 91: ['gravity'], 92: [], 93: ['gravity'], 94: ['gravity'], 95: ['gravity'], 96: ['gravity'], 97: ['gravity'], 98: [], 99: ['gravity'], 100: ['gravity'], 101: ['gravity'], 102: ['gravity', 'planet_type'], 103: [], 104: ['gravity'], 105: ['gravity', 'goldilock'], 106: ['gravity'], 107: ['gravity'], 108: ['gravity'], 109: [], 110: ['gravity'], 111: [], 112: [], 113: ['gravity', 'planet_type', 'speed'], 114: ['gravity', 'planet_type', 'speed'], 115: ['gravity'], 116: ['gravity', 'planet_type', 'speed'], 117: ['gravity'], 118: ['gravity'], 119: ['gravity', 'planet_type'], 120: ['gravity', 'planet_type'], 121: ['gravity', 'planet_type'], 122: ['gravity', 'planet_type'], 123: ['gravity', 'planet_type'], 124: ['gravity', 'planet_type'], 125: ['gravity', 'planet_type'], 126: ['gravity', 'planet_type'], 127: ['gravity', 'planet_type'], 128: ['gravity', 'planet_type'], 129: ['gravity', 'planet_type'], 130: ['gravity', 'planet_type'], 131: ['gravity', 'planet_type', 'speed'], 132: [], 133: ['gravity', 'planet_type'], 134: ['gravity'], 135: ['gravity', 'planet_type'], 136: ['gravity', 'planet_type'], 137: [], 138: [], 139: ['gravity', 'planet_type'], 140: ['gravity', 'planet_type'], 141: [], 142: ['gravity'], 143: [], 144: ['gravity', 'planet_type', 'speed'], 145: [], 146: [], 147: ['gravity', 'goldilock'], 148: ['gravity'], 149: ['gravity'], 150: ['gravity', 'goldilock'], 151: [], 152: ['gravity', 'planet_type', 'speed'], 153: ['gravity', 'goldilock'], 154: ['gravity'], 155: ['gravity', 'goldilock'], 156: ['gravity'], 157: ['gravity', 'planet_type', 'speed'], 158: ['gravity', 'planet_type', 'speed'], 159: ['gravity', 'planet_type', 'speed'], 160: ['gravity', 'planet_type', 'speed'], 161: ['gravity', 'planet_type', 'speed'], 162: ['gravity'], 163: ['gravity', 'goldilock'], 164: [], 165: ['gravity', 'planet_type', 'speed'], 166: [], 167: [], 168: ['gravity', 'planet_type', 'speed'], 169: [], 170: [], 171: [], 172: [], 173: ['goldilock'], 174: ['gravity'], 175: [], 176: [], 177: [], 178: [], 179: [], 180: ['goldilock'], 181: [], 182: ['gravity', 'planet_type', 'speed'], 183: ['gravity', 'planet_type', 'speed'], 184: ['gravity', 'goldilock'], 185: [], 186: ['gravity', 'planet_type', 'speed'], 187: ['gravity', 'planet_ty ...

# %%
goldilock_planet_count = 0

for key , value in final_dict.items():
  if "goldilock" in value:
    goldilock_planet_count += 1

print(goldilock_planet_count)
# Out:
# 414

# %%
speed_planet_count = 0

for key , value in final_dict.items():
  if "speed" in value:
    speed_planet_count += 1

print(speed_planet_count)
# Out:
# 655

# %%
goldilock_gravity_type_count = 0

for key , value in final_dict.items():
  if "goldilock" in value and "planet_type" in value and "gravity" in value:
    goldilock_gravity_type_count += 1

print(goldilock_gravity_type_count)
# Out:
# 22

# %%
all_four_count = 0

for key, value in final_dict.items():
  if "goldilock" in value and "planet_type" in value and "gravity" in value and "speed" in value:
    all_four_count += 1

print(all_four_count)
# Out:
# 22

# %%
final_dict = {}
for index , planet_data in enumerate(planet_data_rows):
  features_list = []
  gravity = (float(planet_data[3]) * 5.972e+24) / (float(planet_data[7]) * float(planet_data[7]) * 6371000 * 6371000) * 6.674e-11
  try:
    if gravity < 100:
      features_list.append("gravity")
  except: pass

  try:
    if planet_data[6].lower() == "terrestrial" or planet_data[6].lower() == "super earth":
      features_list.append("planet_type")
  except:pass

  try:
    if float(planet_data[8].split(" ")[0]) > 0.38 and float(planet_data[8].split(" ")[0]) < 2:
      features_list.append("goldilock")
  except:
    try:
      if planet_data[8] > 0.38 and planet_data[8] < 2:
        features_list.append("goldilock")
    except: pass

  try:
    distance = 2 * 3.14 * (float (planet_data[8].split(" ")[0]) * 1.496e+8)
    time = time * 86400
    speed = distance / time
    if speed < 200:
      features_list.append("speed")
  except: pass

  final_dict[index] = features_list

print(final_dict)
# Out:
# {0: ['goldilock', 'speed'], 1: ['goldilock', 'speed'], 2: ['gravity', 'goldilock', 'speed'], 3: ['gravity', 'speed'], 4: ['gravity', 'goldilock', 'speed'], 5: ['gravity', 'speed'], 6: ['gravity', 'speed'], 7: ['gravity', 'speed'], 8: ['gravity', 'goldilock', 'speed'], 9: ['gravity', 'speed'], 10: ['speed'], 11: ['speed'], 12: ['gravity', 'speed'], 13: ['gravity', 'speed'], 14: ['gravity', 'speed'], 15: ['gravity', 'goldilock', 'speed'], 16: [], 17: ['speed'], 18: ['goldilock', 'speed'], 19: ['gravity', 'goldilock', 'speed'], 20: ['gravity', 'speed'], 21: ['gravity', 'speed'], 22: ['gravity', 'speed'], 23: ['gravity', 'goldilock', 'speed'], 24: ['gravity', 'speed'], 25: ['gravity', 'speed'], 26: ['gravity', 'speed'], 27: ['gravity', 'speed'], 28: ['gravity', 'speed'], 29: ['gravity', 'planet_type'], 30: ['gravity', 'goldilock', 'speed'], 31: ['gravity', 'speed'], 32: ['speed'], 33: ['goldilock', 'speed'], 34: ['gravity', 'speed'], 35: ['gravity', 'goldilock', 'speed'], 36: ['gravity', 'speed'], 37: ['gravity', 'goldilock', 'speed'], 38: ['gravity', 'speed'], 39: ['gravity', 'speed'], 40: ['gravity', 'goldilock', 'speed'], 41: ['gravity', 'goldilock', 'speed'], 42: ['speed'], 43: ['gravity', 'goldilock', 'speed'], 44: ['gravity', 'goldilock', 'speed'], 45: ['gravity', 'speed'], 46: ['gravity', 'goldilock', 'speed'], 47: ['speed'], 48: ['gravity', 'goldilock', 'speed'], 49: ['speed'], 50: ['gravity', 'goldilock', 'speed'], 51: ['gravity', 'speed'], 52: ['gravity', 'speed'], 53: ['speed'], 54: ['gravity', 'goldilock', 'speed'], 55: ['gravity', 'goldilock', 'speed'], 56: ['gravity', 'goldilock', 'speed'], 57: ['gravity', 'goldilock', 'speed'], 58: ['gravity', 'goldilock', 'speed'], 59: ['goldilock', 'speed'], 60: ['speed'], 61: ['gravity', 'goldilock', 'speed'], 62: ['speed'], 63: ['gravity', 'goldilock', 'speed'], 64: ['gravity', 'goldilock', 'speed'], 65: ['gravity', 'speed'], 66: ['gravity', 'goldilock', 'speed'], 67: ['gravity', 'speed'], 68: ['gravity', 'speed'], 69: ['gravity', 'goldilock', 'speed'], 70: ['gravity', 'speed'], 71: ['speed'], 72: ['gravity'], 73: ['gravity', 'speed'], 74: ['gravity', 'speed'], 75: ['gravity', 'speed'], 76: ['gravity', 'speed'], 77: ['gravity', 'speed'], 78: ['gravity', 'speed'], 79: ['gravity', 'speed'], 80: ['gravity', 'speed'], 81: ['gravity', 'speed'], 82: ['gravity', 'speed'], 83: ['gravity', 'speed'], 84: ['speed'], 85: ['gravity', 'speed'], 86: ['speed'], 87: ['gravity', 'speed'], 88: ['speed'], 89: ['speed'], 90: ['gravity', 'speed'], 91: ['gravity', 'speed'], 92: ['speed'], 93: ['gravity', 'speed'], 94: ['gravity', 'speed'], 95: ['gravity', 'speed'], 96: ['gravity', 'speed'], 97: ['gravity', 'speed'], 98: ['speed'], 99: ['gravity', 'speed'], 100: ['gravity', 'speed'], 101: ['gravity', 'speed'], 102: ['gravity', 'planet_type'], 103: ['speed'], 104: ['gravity', 'speed'], 105: ['gravity', 'goldilock', 'speed'], 106: ['gravity', 'speed'], 107: ['gravity', 'speed'], 108: ['gravity', 'speed'], 109: ['speed'], 110: ['gravity', 'speed'], 111: ['speed'], 112: ['speed'], 113: ['gravity', 'planet_type'], 114: ['gravity', 'planet_type'], 115: ['gravity', 'speed'], 116: ['gravity', 'planet_type'], 117: ['gravity', 'speed'], 118: ['gravity'], 119: ['gravity', 'planet_type'], 120: ['gravity', 'planet_type'], 121: ['gravity', 'planet_type'], 122: ['gravity', 'planet_type'], 123: ['gravity', 'planet_type'], 124: ['gravity', 'planet_type'], 125: ['gravity', 'planet_type'], 126: ['gravity', 'planet_type'], 127: ['gravity', 'planet_type'], 128: ['gravity', 'planet_type'], 129: ['gravity', 'planet_type'], 130: ['gravity', 'planet_type'], 131: ['gravity', 'planet_type'], 132: ['speed'], 133: ['gravity', 'planet_type'], 134: ['gravity'], 135: ['gravity', 'planet_type'], 136: ['gravity', 'planet_type'], 137: ['speed'], 138: ['speed'], 139: ['gravity', 'planet_type'], 140: ['gravity', 'planet_type'], 141: ['speed'], 142: ['gravity', 'speed'], 143: ['speed'], 144: ['gravity', 'planet_type'], 145: ['speed'], 146: ...

# %%
goldilock_gravity_type_count = 0

for key , value in  final_dict.items():
  if "goldilock" in value and "planet_type" in value and "gravity" in value:
    goldilock_gravity_type_count +=1

print(goldilock_gravity_type_count)
# Out:
# 22

# %%
all_four_count = 0
for key,value in final_dict.items():
  if "goldilock" in value and "planet_type" in value and "gravity" in value and "speed" in value:
    all_four_count+=1

print(all_four_count)
# Out:
# 0
